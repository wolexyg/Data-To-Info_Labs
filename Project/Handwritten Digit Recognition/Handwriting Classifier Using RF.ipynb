# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('train.csv')

# %%
data.shape
# Out:
# (42000, 785)

# %%
X = data.iloc[:,1:].values
y = data.iloc[:,0:1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=9)

# %%
from sklearn.ensemble import RandomForestClassifier
rforest = RandomForestClassifier()
rforest.fit(X_train , y_train)
# Out:
# F:\anaconda3\lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier()

# %%
y_pred = rforest.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.9621428571428572

# %%
plt.imshow(X_test[99].reshape(28, 28))

# %%
rforest.predict(X_test[99].reshape(1, 784))
# Out:
# array([3], dtype=int64)

# %%
import bz2file as bz2
import pickle

def compressed_pickle(title, data):
  with bz2.BZ2File(title + '.pbz2', 'w') as f:
    pickle.dump(data, f)

compressed_pickle('model2', rforest)
