# %%
import pandas as pd

# %%
df = pd.read_csv('carprices.csv')

# %%
df.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Car Mileage Vs Sell Price

# %%
plt.scatter(df['Mileage'], df['Sell Price($)'])
plt.xlabel('Mileage')
plt.ylabel('Sell Price($)')
# Out:
# Text(0, 0.5, 'Sell Price($)')

# %% [markdown]
# # Car Age Vs Sell Price

# %%
plt.scatter(df['Age(yrs)'], df['Sell Price($)'])
plt.xlabel('Age(yrs)')
plt.ylabel('Sell Price($)')
# Out:
# Text(0, 0.5, 'Sell Price($)')

# %% [markdown]
# **Looking at above two scatter plots, using linear regression model makes sense as we can clearly see a linear relationship between our dependant (i.e. Sell Price) and independant variables (i.e. car age and car mileage)**
#
# The approach we are going to use here is to split available data in two sets
#
# 1. Training: We will train our model on this dataset
# 2. Testing: We will use this subset to make actual predictions using trained model
#
# **The reason we don't use same training set for testing is because our model has seen those samples before, using same samples for making predictions might give us wrong impression about accuracy of our model. It is like you ask same questions in exam paper as you tought the students in the class.**

# %%
df.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
X = df[['Mileage', 'Age(yrs)']]
y = df['Sell Price($)']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
len(X_test)
# Out:
# 4

# %% [markdown]
# # Lets run linear regression model now

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#     Mileage  Age(yrs)
# 2     57000         5
# 14    82450         7
# 19    52000         5
# 16    28000         2

# %%
clf.predict(X_test)
# Out:
# array([26139.56281383, 16445.61033005, 27793.48044456, 37645.55268711])

# %%
y_test
# Out:
# 2     26100
# 14    19400
# 19    28200
# 16    35500
# Name: Sell Price($), dtype: int64

# %%
clf.score(X_test, y_test)*100
# Out:
# 89.76600604981975

# %% [markdown]
# # random_state argument
#
# **We use this to stop randomization. It gives us random value only once and after that it will keep using the same set for all operations.**

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=10)
X_test
# Out:
#     Mileage  Age(yrs)
# 7     72000         6
# 10    83000         7
# 5     59000         5
# 6     52000         5
# 3     22500         2
# 18    87600         8
